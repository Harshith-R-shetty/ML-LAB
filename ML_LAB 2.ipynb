# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('book1.csv')
df
# Out:
#    Unnamed: 0  area   price
# 0           0  2600  550000
# 1           1  3000  565000
# 2           2  3200  610000
# 3           3  3600  680000
# 4           4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area (in sq ft)')
plt.ylabel('price (in USD)')
plt.scatter(df.area, df.price, color='red', marker='*')
plt.plot(df.area, regression_object.predict(df[['area']]))

# %%
regression_object = linear_model.LinearRegression()
regression_object.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
regression_object.predict([[5000]])
# Out:
# C:\Users\Harshith R\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
regression_object.coef_
# Out:
# array([135.78767123])

# %%
regression_object.intercept_
# Out:
# 180616.43835616432

# %%
price = 135.78767123*5000 + 180616.43835616432
price
# Out:
# 859554.7945061643
